# %% [markdown]
# # Quiz 5 - Smartphone Market Data Visualization
#
# - 🏆 25 points available

# %% [markdown]
# ▶️ First, run the code below to import `unittest`, a module used for **🧭 Check Your Work** sections and the autograder.

# %%
# DO NOT MODIFY THE CODE IN THIS CELL
import unittest

tc = unittest.TestCase()

# %% [markdown]
# ▶️ Run the code below to import `pandas`, `numpy`, and `plotly`.

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px

# %% [markdown]
# ▶️ Check your plotly version below. Make sure it is at least version 6.0.0.

# %%
print(f"plotly version: {plotly.__version__}")
# Out:
# plotly version: 6.3.0

# %% [markdown]
# ---
#
# ### 🗃️ Dataset
#
# > The dataset contains over 1000 mobile phone models from popular brands including Apple, Samsung, Xiaomi, Oppo, Vivo, Google, OnePlus, Realme, and Infinix.
#
# - Source: [Global Smartphone Prices Dataset on Kaggle](https://www.kaggle.com/datasets/shahzadi786/world-smartphone-market-2025)

# %% [markdown]
# ▶️ Run the code below to import the dataset as a pandas DataFrame named `df`.

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/bdi475/datasets/refs/heads/main/global-smartphone-prices-2025.csv"
)
df_backup = df.copy()
df.head()
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month  year
# 0       Helio G99     3.8      February  2025
# ...

# %% [markdown]
# ---
#
# ### 🎯 Exercise 1: Number of rows and columns
#
# #### 👇 Tasks
#
# - ✔️ Retrieve the number of rows in `df` to a new variable named `num_rows`.
# - ✔️ Retrieve the number of columns in `df` to a new variable named `num_cols`.
# - ✔️ Both `num_rows` and `num_cols` should be integer types.

# %%
# YOUR CODE BEGINS
num_rows, num_cols = df.shape
# YOUR CODE ENDS

print(f"df contains {num_rows} rows and {num_cols} columns.")
# Out:
# df contains 1000 rows and 15 columns.

# %% [markdown]
# #### 🧭 Check Your Work
#
# Run the code cell below to test your solution.
#
# - ✔️ If the code cell runs without errors, you're good to move on.
# - ❌ If the code cell produces an error, review your code and fix any mistakes.

# %%
_test_case = "part-01"
_points = 2

tc.assertEqual(num_rows, len(df.index), f"Number of rows should be {len(df.index)}")
tc.assertEqual(
    num_cols,
    len(df.columns),
    f"Number of columns should be {len(df.columns)}",
)

# %% [markdown]
# ---
#
# ### 🎯 Exercise 2: Price box plot (horizontal)
#
# #### 👇 Tasks
#
# - ✔️ Draw a horizontal box plot of the `"price_usd"` column.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
#   - A title should describe your plot (e.g., Smartphone Price Distribution).
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.box(
    df,
    x="price_usd",
    orientation="h",
    title="Smartphone Price in USD",
)
fig.show()
# YOUR CODE ENDS

# %% [markdown]
# #### 🔑 Sample output
#
# ![Expected Output](https://github.com/bdi475/images/blob/main/quizzes/05/smartphone-price-boxplot.png?raw=true)

# %% [markdown]
# #### 🧭 Check Your Work
#
# Run the code cell below to test your solution.
#
# - ✔️ If the code cell runs without errors, you're good to move on.
# - ❌ If the code cell produces an error, review your code and fix any mistakes.

# %%
_test_case = "part-02"
_points = 3

tc.assertEqual(len(fig.data), 1, "There must be only one plot in your figure")
tc.assertIsNotNone(fig.layout.title.text, "Missing figure title")
tc.assertEqual(fig.data[0].type, "box", "Not a box plot")
tc.assertEqual(
    fig.data[0].orientation, "h", "Your plot should have a horizontal orientation"
)
np.testing.assert_array_equal(fig.data[0].x, df["price_usd"], "Incorrect data")

# %% [markdown]
# ---
#
# ### 🎯 Exercise3: Price by operating system
#
# #### 👇 Tasks
#
# - ✔️ Draw horizontal box plots of `"price_usd"` by `"os"`.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.box(
    df,
    x="price_usd",
    y="os",
    orientation="h",
    title="Smartphone Price in USD by Operating System",
)
fig.show()
# YOUR CODE ENDS

# %% [markdown]
# #### 🔑 Sample output
#
# ![Expected Output](https://github.com/bdi475/images/blob/main/quizzes/05/smartphone-price-by-os-boxplots.png?raw=true)

# %% [markdown]
# #### 🧭 Check Your Work
#
# Run the code cell below to test your solution.
#
# - ✔️ If the code cell runs without errors, you're good to move on.
# - ❌ If the code cell produces an error, review your code and fix any mistakes.

# %%
_test_case = "part-03"
_points = 5

tc.assertEqual(len(fig.data), 1, "There must be only one plot in your figure")
tc.assertIsNotNone(fig.layout.title.text, "Missing figure title")
tc.assertEqual(fig.data[0].type, "box", "Not a box plot")
tc.assertEqual(
    fig.data[0].orientation, "h", "Your plot should have a horizontal orientation"
)
np.testing.assert_array_equal(fig.data[0].x, df["price_usd"], "Incorrect x-axis data")
np.testing.assert_array_equal(fig.data[0].y, df["os"], "Incorrect y-axis data")

# %% [markdown]
# ---
#
# ### 🎯 Exercise 4: Price histogram
#
# #### 👇 Tasks
#
# - ✔️ Draw a histogram (vertical) of `"price_usd"` in `df`.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.histogram(df, x="price_usd", title="Smartphone Price in USD")
fig.show()
# YOUR CODE ENDS

# %% [markdown]
# #### 🔑 Sample output
#
# ![Expected Output](https://github.com/bdi475/images/blob/main/quizzes/05/smartphone-price-histogram.png?raw=true)

# %% [markdown]
# #### 🧭 Check Your Work
#
# Run the code cell below to test your solution.
#
# - ✔️ If the code cell runs without errors, you're good to move on.
# - ❌ If the code cell produces an error, review your code and fix any mistakes.

# %%
_test_case = "part-04"
_points = 5

tc.assertEqual(len(fig.data), 1, "There must be only one plot in your figure")
tc.assertIsNotNone(fig.layout.title.text, "Missing figure title")
tc.assertEqual(fig.data[0].type, "histogram", "Not a histogram")
tc.assertEqual(
    fig.data[0].orientation, "v", "Your plot should have a vertical orientation"
)
np.testing.assert_array_equal(fig.data[0].x, df["price_usd"], "Incorrect data")

# %% [markdown]
# ---
#
# ### 🎯 Exercise 5: Number of trips by date (Scatter Plot)
#
# #### 👇 Tasks
#
# - ✔️ Using `df`, create a scatter plot with the following columns:
#   - x-axis: `"price_usd"`
#   - y-axis: `"rating"`
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.scatter(
    df,
    x="price_usd",
    y="rating",
    title="Smartphone Price vs Rating",
)
fig.show()
# YOUR CODE ENDS

# %% [markdown]
# #### 🔑 Sample output
#
# ![Expected Output](https://github.com/bdi475/images/blob/main/quizzes/05/smartphone-price-vs-rating-scatter-plot.png?raw=true)

# %% [markdown]
# #### 🧭 Check Your Work
#
# Run the code cell below to test your solution.
#
# - ✔️ If the code cell runs without errors, you're good to move on.
# - ❌ If the code cell produces an error, review your code and fix any mistakes.

# %%
_test_case = "part-05"
_points = 5

tc.assertEqual(len(fig.data), 1, "There must be only one plot in your figure")
tc.assertIsNotNone(fig.layout.title.text, "Missing figure title")
tc.assertEqual(fig.data[0].type, "scatter", "Must be a scatter plot")
tc.assertIsNone(fig.data[0].line.color, "Must be a scatter plot")
np.testing.assert_array_equal(fig.data[0].x, df["price_usd"], "Incorrect x-axis data")
np.testing.assert_array_equal(fig.data[0].y, df["rating"], "Incorrect y-axis data")

# %% [markdown]
# ---
#
# ### 🎯 Exercise 6: Brands breakdown
#
# #### 👇 Tasks
#
# - ✔️ Using `df`, create a pie chart that shows the breakdown of brands (by number of models).
# - ✔️ Set an appropriate title.
# - ✔️ Set the `width` to `800` and `height` to `700`.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.pie(df, names="brand", title="Brands Breakdown", width=800, height=700)

fig.show()
# YOUR CODE ENDS

# %% [markdown]
# #### 🔑 Sample output
#
# ![Expected Output](https://github.com/bdi475/images/blob/main/quizzes/05/smartphone-brands-breakdown-pie-chart.png?raw=true)

# %% [markdown]
# #### 🧭 Check Your Work

# %%
_test_case = "part-06"
_points = 5

tc.assertIsNotNone(fig.layout.title.text, "Missing figure title")
tc.assertEqual(fig.data[0].type, "pie", "Must be a pie chart")
tc.assertEqual(
    set(fig.data[0].labels), set(df["brand"]), "Must only use the top 20 neighbourhoods"
)
tc.assertEqual(fig.layout.width, 800, "Incorrect width")
tc.assertEqual(fig.layout.height, 700, "Incorrect height")
