# %% [markdown]
# # Exercise 12 (following Lecture 13)
#
# Wednesday 2021/03/10

# %% [markdown]
# ▶️ First, run the code cell below to import `unittest`, a module used for **🧭 Check Your Work** sections and the autograder.

# %%
import unittest
tc = unittest.TestCase()

# %% [markdown]
# ---
#
# ### 🎯 Exercise 1: Import `numpy` and `pandas`

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Import the following Python packages.
#     1. `pandas`: Use alias `pd`.
#     2. `numpy`: Use alias `np`.

# %%
# YOUR CODE BEGINS
import pandas as pd
import numpy as np
# YOUR CODE ENDS

# %% [markdown]
# #### 🧭 Check your work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
tc.assertTrue('pd' in globals(), 'Check whether you have correctly import Pandas with an alias.')
tc.assertTrue('np' in globals(), 'Check whether you have correctly import NumPy with an alias.')

# %% [markdown]
# ---
#
# ### 📌 Load data

# %% [markdown]
# ▶️ Run the code cell below to create a new `DataFrame` named `df_you` from a CSV file.
#
# Your name might not be here if you haven't filled out the "Introduce You" survey on the course Discord channel. 😬 If you'd like me to add you into the list, please feel free to email me (ypark32@illinois.edu)! I'd love to have everyone on the list.

# %%
df_you = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Used to keep a clean copy
df_you_backup = df_you.copy()

# Display df_you
df_you
# Out:
#         name                               major1                   major2  \
# 0   Citlalli                         Anthropology                      NaN
# 1       Zach                              Finance      Information Systems
# 2        Ori                  Information Science                      NaN
# 3      Dylan                          Accountancy                      NaN
# 4       Ajay            Organizational Psychology               Statistics
# 5     Andrew                            Economics               Statistics
# 6      Sarah                            Marketing                  Theatre
# 7     Ahsaas                              Finance                      NaN
# 8   Jennifer                         Food Science          Human Nutrition
# 9       Ella                          Accountancy                      NaN
# 10     James                          Accountancy              Informatics
# ...

# %% [markdown]
# The table below describes each column in `df_you`.

# %% [markdown]
# | Column Name             | Description                                               |
# |-------------------------|-----------------------------------------------------------|
# | name                    | First name                                                |
# | major1                  | Major                                                     |
# | major2                  | Second major OR minor (blank if no second major or minor) |
# | city                    | City the person is from                                   |
# | distance_from_champaign | Straight distance from the city to Champaign in miles     |
# | fav_restaurant          | Favorite restaurant (blank if no restaurant was given)    |
# | has_iphone              | Whether the person use an iPhone                          |

# %% [markdown]
# ---
#
# ### 🎯 Exercise 2: Find of number of rows and columns in a `DataFrame`

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Store the number of rows in `df_you` to a new variable named `num_rows`.
# - ✔️ Store the number of columns in `df_you` to a new variable named `num_cols`.
# - ✔️ Both `num_rows` and `num_cols` must be integers.
# - ✔️ Use `.shape`, not `len()`.

# %%
# YOUR CODE BEGINS
num_rows = df_you.shape[0]
num_cols = df_you.shape[1]

print(num_rows)
print(num_cols)
# YOUR CODE ENDS
# Out:
# 40
# 7

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
tc.assertEqual(num_rows, len(df_you.index), f'Number of rows should be {len(df_you.index)}')
tc.assertEqual(num_cols, len(df_you.columns), f'Number of columns should be {len(df_you.columns)}')

# %% [markdown]
# ---
#
# ### 🎯 Exercise 3: People who likes Portillos

# %% [markdown]
# ▶️ Run the code cell below to see the **first** 3 rows of `df_you`.

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Display the first three rows
df_you.head(3)
# Out:
#        name               major1               major2      city  \
# 0  Citlalli         Anthropology                  NaN   Chicago
# 1      Zach              Finance  Information Systems  Glenview
# 2       Ori  Information Science                  NaN    Skokie
#
#    distance_from_champaign fav_restaurant  has_iphone
# 0                   125.86   Seven Saints        True
# 1                   137.04            NaN       False
# 2                   134.94        Culvers        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person's favorite restaurant is Portillos.
#     - Store the result to a new variable named `df_portillos`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_portillos = df_you[df_you['fav_restaurant'] == 'Portillos']
# YOUR CODE ENDS

df_portillos
# Out:
#       name                   major1       major2         city  \
# 14  Jackie  Supply Chain Management    Marketing     Wheeling
# 27   Erisa                Chemistry  Informatics  Lake Forest
#
#     distance_from_champaign fav_restaurant  has_iphone
# 14                   397.48      Portillos        True
# 27                   149.48      Portillos        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
pd.testing.assert_frame_equal(df_you, df_you_clean);

# Check filtered rows
fav_restaurant_to_search = "".join([' ', 'P', 'o', 'r', 't', 'i', 'l', 'l', 'o', 's', ' ']).strip()
df_you_check = df_you_clean[df_you_clean['fav_restaurant'].eq(fav_restaurant_to_search)]
pd.testing.assert_frame_equal(df_portillos.sort_values(df_portillos.columns.tolist()).reset_index(drop=True),
                              df_you_check.sort_values(df_you_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Exercise 4: People who are within 100 miles radius from Champaign.

# %% [markdown]
# ▶️ Run the code cell below to see the **last** 3 rows of `df_you`.

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Display the last three rows
df_you.tail(3)
# Out:
#      name                               major1     major2                city  \
# 37  Tyler                  Information Systems        NaN  Homewood-Flossmoor
# 38    Joe  Agricultural and Consumer Economics  Marketing             Chicago
# 39  Clint                    Political Science        NaN         Springfield
#
#     distance_from_champaign fav_restaurant  has_iphone
# 37                   134.94  Lou Malnati's        True
# 38                   125.86            NaN       False
# 39                    85.11       Chipotle        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person is from a city that is within 100 miles from Champaign.
#     - Use the `distance_from_champaign` column.
#     - Store the result to a new variable named `df_nearby`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_nearby = df_you[df_you['distance_from_champaign'] <= 100]
# YOUR CODE ENDS

df_nearby
# Out:
#      name             major1   major2         city  distance_from_champaign  \
# 6   Sarah          Marketing  Theatre       Morris                    86.38
# 30   Mark            Finance      NaN     Metamora                    74.97
# 39  Clint  Political Science      NaN  Springfield                    85.11
#
#    fav_restaurant  has_iphone
# 6             NaN        True
# 30      Taco Bell       False
# 39       Chipotle        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
pd.testing.assert_frame_equal(df_you, df_you_clean);

# Check filtered rows
miles_radius = int(int("50") + float("30") + float("20"))
df_you_check = df_you_clean[df_you_clean['distance_from_champaign'].le(miles_radius)]
pd.testing.assert_frame_equal(df_nearby.sort_values(df_nearby.columns.tolist()).reset_index(drop=True),
                              df_you_check.sort_values(df_you_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Exercise 5: People who have `Informatics` in `major2`

# %% [markdown]
# ▶️ Run the code cell below to **randomly select** 3 rows from `df_you`.

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Randomly select three rows
df_you.sample(3)
# Out:
#       name               major1      major2         city  \
# 13    Nick  Information Science         NaN   Northbrook
# 36     Jim          Accountancy         NaN  Orland Park
# 5   Andrew            Economics  Statistics       Skokie
#
#     distance_from_champaign fav_restaurant  has_iphone
# 13                   140.84       Potbelly        True
# 36                   106.11       Chipotle        True
# 5                    134.94            NaN        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person's `major2` is `Informatics`.
#     - You're only using **`major2`**, not **`major1`**.
#     - Store the result to a new variable named `df_major2_informatics`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_major2_informatics = df_you[df_you['major2'] == 'Informatics']
# YOUR CODE ENDS

df_major2_informatics
# Out:
#      name       major1       major2             city  distance_from_champaign  \
# 10  James  Accountancy  Informatics      Orland Park                   106.11
# 12    Max      Finance  Informatics  Clarendon Hills                   117.12
# 26   Jake  Accountancy  Informatics      Orland Park                   106.11
# 27  Erisa    Chemistry  Informatics      Lake Forest                   149.48
#
#    fav_restaurant  has_iphone
# 10            NaN        True
# 12    Chick-fil-A        True
# 26       Chipotle        True
# 27      Portillos        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
pd.testing.assert_frame_equal(df_you, df_you_clean);

# Check filtered rows
major2_to_match = "".join([' ', 'In', 'fo', 'rm', 'at', 'ic', 's ']).strip()
df_you_check = df_you_clean[df_you_clean['major2'].eq(major2_to_match)]
pd.testing.assert_frame_equal(df_major2_informatics.sort_values(df_major2_informatics.columns.tolist()).reset_index(drop=True),
                              df_you_check.sort_values(df_you_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Exercise 6: `Marketing` majors/minors

# %% [markdown]
# ![bad-marketing-joke](https://github.com/bdi475/images/blob/main/marketing-joke-second-page-of-google.png?raw=true)

# %% [markdown]
# ▶️ Run the code cell below to **randomly select** 3 rows from `df_you`.

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Randomly select three rows
df_you.sample(3)
# Out:
#         name                   major1           major2         city  \
# 28    Bianca  Supply Chain Management        Marketing        Niles
# 10     James              Accountancy      Informatics  Orland Park
# 8   Jennifer             Food Science  Human Nutrition        Macau
#
#     distance_from_champaign fav_restaurant  has_iphone
# 28                   133.44            NaN        True
# 10                   106.11            NaN        True
# 8                   7807.02            NaN        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows that matches the following criteria:
#     - The person's `major1` is `Marketing`, **OR**
#     - The person's `major2` is `Marketing`.
# - ✔️ In other words, you're looking for anyone who has `Marketing` in either `major1` **or** `major2` columns.
# - ✔️ Store the filtered `DataFrame` to a new variable named `df_marketers`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_marketers = df_you[(df_you['major1'] == 'Marketing') | (df_you['major2'] == 'Marketing')]
# YOUR CODE ENDS

df_marketers
# Out:
#       name                               major1     major2      city  \
# 6    Sarah                            Marketing    Theatre    Morris
# 14  Jackie              Supply Chain Management  Marketing  Wheeling
# 28  Bianca              Supply Chain Management  Marketing     Niles
# 38     Joe  Agricultural and Consumer Economics  Marketing   Chicago
#
#     distance_from_champaign fav_restaurant  has_iphone
# 6                     86.38            NaN        True
# 14                   397.48      Portillos        True
# 28                   133.44            NaN        True
# 38                   125.86            NaN       False

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
pd.testing.assert_frame_equal(df_you, df_you_clean);

# Check filtered rows
major_to_match = "".join([' ', 'M', 'ar', 'ke', 'ti', 'n', 'g ']).strip()
df_you_check = df_you_clean[np.logical_or(df_you_clean['major1'].eq(major_to_match),
                                          df_you_clean['major2'].eq(major_to_match))]
pd.testing.assert_frame_equal(df_marketers.sort_values(df_marketers.columns.tolist()).reset_index(drop=True),
                              df_you_check.sort_values(df_you_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Exercise 7: Accountants from Seoul

# %% [markdown]
# ![bad-accy-joke](https://github.com/bdi475/images/blob/main/accounting-joke-everybody-counts.png?raw=true)

# %% [markdown]
# ▶️ Run the code cell below to **randomly select** 3 rows from `df_you`.

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Randomly select three rows
df_you.sample(3)
# Out:
#       name                   major1     major2       city  \
# 11  Jaewon         Acturial Science        NaN      Seoul
# 9     Ella              Accountancy        NaN  Hong Kong
# 28  Bianca  Supply Chain Management  Marketing      Niles
#
#     distance_from_champaign fav_restaurant  has_iphone
# 11                  6623.70    Jimmy Johns        True
# 9                   7789.61            NaN        True
# 28                   133.44            NaN        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows that matches both of the following two criteria:
#     - The person's `major1` is `Accountancy`, **AND**
#     - The person's `city` is `Seoul`.
# - ✔️ Store the filtered `DataFrame` to a new variable named `df_seoul_accy`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_seoul_accy = df_you[(df_you['major1'] == 'Accountancy') & (df_you['city'] == 'Seoul')]
# YOUR CODE ENDS

df_seoul_accy
# Out:
#        name       major1                   major2   city  \
# 22    Bella  Accountancy      Information Systems  Seoul
# 25  Hwanjae  Accountancy  Technology & Management  Seoul
#
#     distance_from_champaign fav_restaurant  has_iphone
# 22                   6623.7            NaN        True
# 25                   6623.7            NaN        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
pd.testing.assert_frame_equal(df_you, df_you_clean);

# Check filtered rows
major_to_match = "".join([' ', 'A', 'cc', 'ou', 'nt', 'an', 'cy ']).strip()
city_to_match = "".join(['   ', 'S', 'e', 'o', 'u', 'l', '   ']).strip()
df_you_check = df_you_clean[np.logical_and(df_you_clean['major1'].eq(major_to_match),
                                           df_you_clean['city'].eq(city_to_match))]
pd.testing.assert_frame_equal(df_seoul_accy.sort_values(df_marketers.columns.tolist()).reset_index(drop=True),
                              df_you_check.sort_values(df_you_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Exercise 8: Anyone that does not use an iPhone

# %% [markdown]
# ▶️ Run the code cell below to **randomly select** 3 rows from `df_you`.

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Randomly select three rows
df_you.sample(3)
# Out:
#       name                  major1      major2         city  \
# 39   Clint       Political Science         NaN  Springfield
# 31  Yushan             Accountancy  Statistics      Nanjing
# 20   Dylan  Learning and Education         NaN      Chicago
#
#     distance_from_champaign fav_restaurant  has_iphone
# 39                    85.11       Chipotle        True
# 31                  7159.39            NaN        True
# 20                   125.86            NaN        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person does not have an iPhone.
# - ✔️ Store the filtered `DataFrame` to a new variable named `df_no_iphone`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_no_iphone = df_you[~df_you['has_iphone']]
# YOUR CODE ENDS

df_no_iphone
# Out:
#         name                               major1               major2  \
# 1       Zach                              Finance  Information Systems
# 30      Mark                              Finance                  NaN
# 34  Michelle                          Accountancy                  NaN
# 38       Joe  Agricultural and Consumer Economics            Marketing
#
#         city  distance_from_champaign fav_restaurant  has_iphone
# 1   Glenview                   137.04            NaN       False
# 30  Metamora                    74.97      Taco Bell       False
# 34   Chicago                   125.86            NaN       False
# 38   Chicago                   125.86            NaN       False

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
pd.testing.assert_frame_equal(df_you, df_you_clean);

# Check filtered rows
df_you_check = df_you_clean[np.logical_not(df_you_clean['_'.join(['has', 'iphone'])])]
pd.testing.assert_frame_equal(df_no_iphone.sort_values(df_marketers.columns.tolist()).reset_index(drop=True),
                              df_you_check.sort_values(df_you_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Exercise 9: Select 1 row

# %% [markdown]
# ▶️ Run the code cell below to display **all rows** in `df_you` (depending on your notebook's *maximum number of rows displayed* settings, you may see only part of your `df_you` DataFrame).

# %%
# Reset df_you in case the user altered it accidentally
df_you = df_you_backup.copy()

# Display all rows
df_you
# Out:
#         name                               major1                   major2  \
# 0   Citlalli                         Anthropology                      NaN
# 1       Zach                              Finance      Information Systems
# 2        Ori                  Information Science                      NaN
# 3      Dylan                          Accountancy                      NaN
# 4       Ajay            Organizational Psychology               Statistics
# 5     Andrew                            Economics               Statistics
# 6      Sarah                            Marketing                  Theatre
# 7     Ahsaas                              Finance                      NaN
# 8   Jennifer                         Food Science          Human Nutrition
# 9       Ella                          Accountancy                      NaN
# 10     James                          Accountancy              Informatics
# ...

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, select only 1 row using any filter.
#     - **If you're on the list**, you must select yourself.
#     - **If you're not on the list**, select any row.
# - ✔️ Store the filtered `DataFrame` to a new variable named `df_chosen_one`.
# - ✔️ `df_chosen_one` should only have a single row.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_chosen_one = df_you[df_you['name'] == 'Joe']
# YOUR CODE ENDS

df_chosen_one
# Out:
#    name                               major1     major2     city  \
# 38  Joe  Agricultural and Consumer Economics  Marketing  Chicago
#
#     distance_from_champaign fav_restaurant  has_iphone
# 38                   125.86            NaN       False

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_you_clean = pd.read_csv('https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv')

# Original DataFrame should remain unaltered
tc.assertEqual(df_chosen_one.shape, (1, len(df_you_clean.columns)))

# %% [markdown]
# ---
#
# ## 🍸 Submitting your notebook

# %% [markdown]
# There is one final step before exporting the notebook as an `.ipynb` file for submission. You should restart your runtime (kernal) and run all cells from the beginning to ensure that your notebook is structured properly.
#
# Go to the **"Runtime"** menu on top. Select **"Restart and run all"**. Failing to pass this step may result in significant loss of points since the autograder will fail to run.<br /><br />
#
# ![image.png](data:image/png;base64,...)

# %%
print('🎯 Restart and run all successful')
# Out:
# 🎯 Restart and run all successful
