# %% [markdown]
# # Clean Leasing Company Google Reviews
#
# Use this starter notebook to load raw data files.

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Load data
#
# ### Businesses and reviews
#
# Read the CSV files. These are [Outscraper](https://outscraper.com/)'s scraped output. They contain Google reviews for leasing companies, apartment complexes, and student housing for three different campustowns.
#
# - Brigham Young University (Provo, UT)
# - Penn State University (University Park, PA)
# - University of Illinois at Urbana Champaign (Champaign, IL)

# %%
df_byu_b = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/byu-businesses.csv')
df_byu_r = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/byu-reviews.csv')
df_psu_b = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/psu-businesses.csv')
df_psu_r = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/psu-reviews.csv')
df_uiuc_b = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/uiuc-businesses.csv')
df_uiuc_r = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/uiuc-reviews.csv')

# %%
display(df_byu_b.head(2))
display(df_byu_r.head(2))
display(df_psu_b.head(2))
display(df_psu_r.head(2))
display(df_uiuc_b.head(2))
display(df_uiuc_r.head(2))
# Out:
#                          query                  name  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I        Alpine Village
# 1  ChIJGbnTbamQTYcRtZfBrL52jhs  Palladium Apartments
#
#                               site                    type  \
# 0     https://myalpinevillage.com/  Student housing center
# 1  https://www.palladiumprovo.com/         Housing complex
#
#                                             subtypes                category  \
# 0  Student housing center, Apartment building, Ap...  Student housing center
# 1                                    Housing complex         Housing complex
#
#              phone                                       full_address  \
# 0  +1 801-623-6093  1378 Freedom Blvd 200 W, Provo, UT 84604, Unit...
# 1  +1 385-200-0510           538 N Freedom Blvd Unit, Provo, UT 84601
#
#        borough                   street   city  postal_code state us_state  \
# 0  Carterville  1378 Freedom Blvd 200 W  Provo        84604  Utah     Utah
# 1   North Park  538 N Freedom Blvd Unit  Provo        84601  Utah     Utah
#
#                     country country_code   latitude   longitude  \
# 0  United States of America           US  40.252607 -111.661247
# 1  United States of America           US  40.240917 -111.661714
#
#         time_zone    plus_code  area_service  rating  reviews  \
# 0  America/Denver  85GC783Q+2G         False     2.9      481
# 1  America/Denver  85GC68RQ+98         False     3.8       22
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
#
#                                         reviews_tags  reviews_per_score  \
# 0  apartment, utilities, fees, checks, contract, ...                NaN
# 1                                  management, space                NaN
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                  200                   33                   31
# 1                    6                    0                    1
#
#    reviews_per_score_4  reviews_per_score_5  photos_count  \
# 0                   72                  145           126
# 1                    1                   14             2
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipPYc7...
# 1  https://lh5.googleusercontent.com/p/AF1QipO0-D...
#
#                                          street_view  located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipOf2I...         NaN
# 1  https://streetviewpixels-pa.googleapis.com/v1/...         NaN
#
#                                        working_hours  \
# 0  {"Monday": "10AM-6PM", "Tuesday": "10AM-6PM", ...
# 1  {"Monday": "9AM-4:30PM", "Tuesday": "9AM-4:30P...
#
#                             working_hours_old_format other_hours  \
# 0  Monday:10AM-6PM|Tuesday:10AM-6PM|Wednesday:10A...         NaN
# 1  Monday:9AM-4:30PM|Tuesday:9AM-4:30PM|Wednesday...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
#
#                                                about  range posts  \
# 0  {"Accessibility": {"Wheelchair-accessible car ...    NaN   NaN
# 1  {"Accessibility": {"Wheelchair accessible entr...    NaN   NaN
#
#                                                 logo  \
# 0  https://lh5.googleusercontent.com/-hH8E8pq9CkI...
# 1  https://lh6.googleusercontent.com/-PTsCf3bop-M...
#
#                                          description  typical_time_spent  \
# 0  Welcome to our accommodating student housing a...                 NaN
# 1  Step into Palladium and you'll have found your...                 NaN
#
#    verified               owner_id           owner_title  \
# 0      True  106402413364201152471        Alpine Village
# 1      True  112123346924561479475  Palladium Apartments
#
#                                           owner_link  reservation_links  \
# 0  https://www.google.com/maps/contrib/1064024133...                NaN
# 1  https://www.google.com/maps/contrib/1121233469...                NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Alpine+Villa...
# 1  https://www.google.com/maps/place/Palladium+Ap...
#
#                       place_id                              google_id  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I  0x874d90a1a3f225ab:0xf2736a8a78e0675c
# 1  ChIJGbnTbamQTYcRtZfBrL52jhs  0x874d90a96dd3b919:0x1b8e76beacc197b5
#
#                     cid           reviews_id  located_google_id
# 0  17470424522466289500  -976319551243262116                NaN
# 1   1985655047031199669  1985655047031199669                NaN
#                          query            name  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I  Alpine Village
# 1  ChIJqyXyo6GQTYcRXGfgeIpqc_I  Alpine Village
#
#                                google_id                     place_id  \
# 0  0x874d90a1a3f225ab:0xf2736a8a78e0675c  ChIJqyXyo6GQTYcRXGfgeIpqc_I
# 1  0x874d90a1a3f225ab:0xf2736a8a78e0675c  ChIJqyXyo6GQTYcRXGfgeIpqc_I
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Alpine+Villa...
# 1  https://www.google.com/maps/place/Alpine+Villa...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      481     2.9
# 1  https://search.google.com/local/reviews?placei...      481     2.9
#
#                               review_id review_pagination_id  \
# 0  ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB     CAESBkVnSUlBUQ==
# 1   ChZDSUhNMG9nS0VJQ0FnSUNwOUstOVpBEAE     CAESBkVnSUlBZw==
#
#                                          author_link    author_title  \
# 0  https://www.google.com/maps/contrib/1005120670...     Laura Brown
# 1  https://www.google.com/maps/contrib/1029361078...  Pete Haraguchi
#
#                author_id                                       author_image  \
# 0  100512067005706825621  https://lh3.googleusercontent.com/a-/ALV-UjUJV...
# 1  102936107836751613731  https://lh3.googleusercontent.com/a-/ALV-UjWJc...
#
#                                          review_text  \
# 0  Service requests take a very long time to be r...
# 1  I was thinking about giving two stars but I le...
#
#                                       review_img_url  \
# 0                                                NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipPeIy...
#
#                                      review_img_urls  review_questions  \
# 0                                                NaN               NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipPeIy...               NaN
#
#                                     review_photo_ids  \
# 0                                                NaN
# 1  AF1QipPeIyT2ml2Z-Lnkg1OUJcOXNWr9EauKExNDhPPw, ...
#
#                                         owner_answer  owner_answer_timestamp  \
# 0  Dear Laura, \n\n We hear you loud and clear, t...            1.698159e+09
# 1  Pete,\n\n Thank you for letting us know about ...            1.690671e+09
#
#   owner_answer_timestamp_datetime_utc  \
# 0                 10/24/2023 14:56:01
# 1                 07/29/2023 22:46:48
#
#                                          review_link  review_rating  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...              3
# 1  https://www.google.com/maps/reviews/data=!4m8!...              1
#
#    review_timestamp  review_datetime_utc  review_likes          reviews_id  \
# 0        1698151603  10/24/2023 12:46:43             0 -976319551243262116
# 1        1690662626  07/29/2023 20:30:26            12 -976319551243262116
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                  200                   33                   31
# 1                  200                   33                   31
#
#    reviews_per_score_4  reviews_per_score_5
# 0                   72                  145
# 1                   72                  145
#                          query                  name  \
# 0  ChIJV2hrraCozokRtlPCp8iIpzs  Park Hill Apartments
# 1  ChIJgTu-OpqozokROgf58b0KflQ     College West, LLC
#
#                                                 site                     type  \
# 0  https://www.liveparkhill.com/?utm_source=Googl...        Apartment complex
# 1                         http://collegewestllc.com/  Apartment rental agency
#
#                                     subtypes                 category  \
# 0  Apartment complex, Student housing center        Apartment complex
# 1                    Apartment rental agency  Apartment rental agency
#
#              phone                               full_address borough  \
# 0  +1 814-636-8515  478 E Beaver Ave, State College, PA 16801     NaN
# 1  +1 814-238-4938       422 Clay Ln, State College, PA 16801     NaN
#
#              street           city  postal_code         state      us_state  \
# 0  478 E Beaver Ave  State College        16801  Pennsylvania  Pennsylvania
# 1       422 Clay Ln  State College        16801  Pennsylvania  Pennsylvania
#
#                     country country_code   latitude  longitude  \
# 0  United States of America           US  40.797899 -77.853648
# 1  United States of America           US  40.791495 -77.866328
#
#           time_zone    plus_code  area_service  rating  reviews  \
# 0  America/New_York  87G4Q4XW+5G         False     4.7      174
# 1  America/New_York  87G4Q4RM+HF         False     3.6       28
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
#
#                                         reviews_tags  reviews_per_score  \
# 0  management, team, renovated, amenities, studen...                NaN
# 1                                  call, prices, pay                NaN
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                    5                    2                    3
# 1                    9                    0                    1
#
#    reviews_per_score_4  reviews_per_score_5  photos_count  \
# 0                   17                  147            63
# 1                    1                   17             1
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipNBlh...
# 1  https://streetviewpixels-pa.googleapis.com/v1/...
#
#                                          street_view  located_in  \
# 0  https://streetviewpixels-pa.googleapis.com/v1/...         NaN
# 1  https://streetviewpixels-pa.googleapis.com/v1/...         NaN
#
#                                        working_hours  \
# 0  {"Monday": "10AM-6PM", "Tuesday": "10AM-6PM", ...
# 1  {"Monday": "10:30AM-5PM", "Tuesday": "10:30AM-...
#
#                             working_hours_old_format  other_hours  \
# 0  Monday:10AM-6PM|Tuesday:10AM-6PM|Wednesday:10A...          NaN
# 1  Monday:10:30AM-5PM|Tuesday:10:30AM-5PM|Wednesd...          NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
#
#                                                about  range posts  \
# 0  {"Accessibility": {"Wheelchair accessible entr...    NaN   NaN
# 1  {"Accessibility": {"Wheelchair accessible entr...    NaN   NaN
#
#                                                 logo  \
# 0  https://lh6.googleusercontent.com/-y7FtFBrdnCo...
# 1                                                NaN
#
#                                          description  typical_time_spent  \
# 0  Something refreshed and better is here! Now un...                 NaN
# 1                                                NaN                 NaN
#
#    verified               owner_id           owner_title  \
# 0      True  106304177199335709332  Park Hill Apartments
# 1     False                    NaN     College West, LLC
#
#                                           owner_link  reservation_links  \
# 0  https://www.google.com/maps/contrib/1063041771...                NaN
# 1                                                NaN                NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Park+Hill+Ap...
# 1  https://www.google.com/maps/place/College+West...
#
#                       place_id                              google_id  \
# 0  ChIJV2hrraCozokRtlPCp8iIpzs  0x89cea8a0ad6b6857:0x3ba788c8a7c253b6
# 1  ChIJgTu-OpqozokROgf58b0KflQ  0x89cea89a3abe3b81:0x547e0abdf1f9073a
#
#                    cid           reviews_id  located_google_id
# 0  4298554764737794998  4298554764737794998                NaN
# 1  6088315557176215354  6088315557176215354                NaN
#                          query                  name  \
# 0  ChIJV2hrraCozokRtlPCp8iIpzs  Park Hill Apartments
# 1  ChIJV2hrraCozokRtlPCp8iIpzs  Park Hill Apartments
#
#                                google_id                     place_id  \
# 0  0x89cea8a0ad6b6857:0x3ba788c8a7c253b6  ChIJV2hrraCozokRtlPCp8iIpzs
# 1  0x89cea8a0ad6b6857:0x3ba788c8a7c253b6  ChIJV2hrraCozokRtlPCp8iIpzs
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Park+Hill+Ap...
# 1  https://www.google.com/maps/place/Park+Hill+Ap...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...      174     4.7
# 1  https://search.google.com/local/reviews?placei...      174     4.7
#
#                               review_id review_pagination_id  \
# 0   ChZDSUhNMG9nS0VJQ0FnSURwbWJDaUdnEAE     CAESBkVnSUlBUQ==
# 1  ChdDSUhNMG9nS0VJQ0FnSURwNHEycHhBRRAB     CAESBkVnSUlBZw==
#
#                                          author_link    author_title  \
# 0  https://www.google.com/maps/contrib/1164123127...  Molly Harrison
# 1  https://www.google.com/maps/contrib/1128985423...         L Davis
#
#                author_id                                       author_image  \
# 0  116412312721973164291  https://lh3.googleusercontent.com/a/ACg8ocL6vI...
# 1  112898542308669426380  https://lh3.googleusercontent.com/a-/ALV-UjWtI...
#
#                                          review_text  \
# 0  I moved into the 1 bedroom deluxe apartment wi...
# 1  I just have to say that the staff at Park Hill...
#
#                                       review_img_url  \
# 0  https://lh5.googleusercontent.com/p/AF1QipOdhs...
# 1                                                NaN
#
#                                      review_img_urls  review_questions  \
# 0  https://lh5.googleusercontent.com/p/AF1QipOdhs...               NaN
# 1                                                NaN               NaN
#
#                                     review_photo_ids  \
# 0  AF1QipOdhs7G7OStqD2pt9JhkQ8E54QdwrM2c6eAeRXu, ...
# 1                                                NaN
#
#                                         owner_answer  owner_answer_timestamp  \
# 0  Thank you for your feedback, Molly. We are tha...            1.693026e+09
# 1  We are so pleased to hear that you enjoyed mov...            1.692456e+09
#
#   owner_answer_timestamp_datetime_utc  \
# 0                 08/26/2023 05:00:14
# 1                 08/19/2023 14:40:54
#
#                                          review_link  review_rating  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...              3
# 1  https://www.google.com/maps/reviews/data=!4m8!...              5
#
#    review_timestamp  review_datetime_utc  review_likes           reviews_id  \
# 0        1692906499  08/24/2023 19:48:19             1  4298554764737794998
# 1        1692395550  08/18/2023 21:52:30             0  4298554764737794998
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                    5                    2                    3
# 1                    5                    2                    3
#
#    reviews_per_score_4  reviews_per_score_5
# 0                   17                  147
# 1                   17                  147
#                          query                           name  \
# 0  ChIJMStDGsrXDIgRyPNO_VtZBPk  Stone Ridge Square Apartments
# 1  ChIJ0yehl6XXDIgRtqPdtmcuKeU                 ICON Apartment
#
#                                                 site                     type  \
# 0  https://www.m2regroup.com/properties/stone-rid...  Apartment rental agency
# 1                     https://www.iconchampaign.com/       Apartment building
#
#                                      subtypes                 category  \
# 0  Apartment rental agency, Apartment complex  Apartment rental agency
# 1                          Apartment building       Apartment building
#
#              phone                                full_address  borough  \
# 0  +1 217-337-6567       1714 E Colorado Ave, Urbana, IL 61802      NaN
# 1  +1 217-352-7945  309 E Springfield Ave, Champaign, IL 61820  Midtown
#
#                   street       city  postal_code     state  us_state  \
# 0    1714 E Colorado Ave     Urbana        61802  Illinois  Illinois
# 1  309 E Springfield Ave  Champaign        61820  Illinois  Illinois
#
#                     country country_code   latitude  longitude  \
# 0  United States of America           US  40.094909 -88.187146
# 1  United States of America           US  40.112279 -88.234493
#
#          time_zone    plus_code  area_service  rating  reviews  \
# 0  America/Chicago  86GH3RV7+X4         False     4.5       78
# 1  America/Chicago  86GH4Q68+W6         False     4.6       19
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
#
#                                         reviews_tags  reviews_per_score  \
# 0  price, community, maintenance, pool, managemen...                NaN
# 1                  property manager, leasing, campus                NaN
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                    5                    3                    1
# 1                    2                    0                    0
#
#    reviews_per_score_4  reviews_per_score_5  photos_count  \
# 0                   11                   58             6
# 1                    0                   17            20
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipNf4R...
# 1  https://lh5.googleusercontent.com/p/AF1QipOwn4...
#
#                                          street_view  located_in  \
# 0  https://streetviewpixels-pa.googleapis.com/v1/...         NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipOQ9k...         NaN
#
#                                        working_hours  \
# 0  {"Monday": "8AM-5PM", "Tuesday": "8AM-5PM", "W...
# 1                                                NaN
#
#                             working_hours_old_format  other_hours  \
# 0  Monday:8AM-5PM|Tuesday:8AM-5PM|Wednesday:8AM-5...          NaN
# 1                                                NaN          NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
#
#                                                about  range  \
# 0  {"Accessibility": {"Wheelchair accessible entr...    NaN
# 1  {"Accessibility": {"Wheelchair accessible entr...    NaN
#
#                                                posts  \
# 0                                                NaN
# 1  [{"body": "6 Studios to go for Fall 2024! We a...
#
#                                                 logo  \
# 0  https://lh6.googleusercontent.com/-KcJVo_Nvrh4...
# 1  https://lh5.googleusercontent.com/-l7qdC33EaDE...
#
#                                          description  typical_time_spent  \
# 0                                                NaN                 NaN
# 1  Icon is an apartment complex newly built in 20...                 NaN
#
#    verified               owner_id                    owner_title  \
# 0      True  115113977329242277127  Stone Ridge Square Apartments
# 1      True  113368691300339480058                 ICON Apartment
#
#                                           owner_link  reservation_links  \
# 0  https://www.google.com/maps/contrib/1151139773...                NaN
# 1  https://www.google.com/maps/contrib/1133686913...                NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Stone+Ridge+...
# 1  https://www.google.com/maps/place/ICON+Apartme...
#
#                       place_id                              google_id  \
# 0  ChIJMStDGsrXDIgRyPNO_VtZBPk  0x880cd7ca1a432b31:0xf904595bfd4ef3c8
# 1  ChIJ0yehl6XXDIgRtqPdtmcuKeU  0x880cd7a597a127d3:0xe5292e67b6dda3b6
#
#                     cid           reviews_id  located_google_id
# 0  17943565066977604552  -503179006731947064                NaN
# 1  16512780531715122102 -1933963541994429514                NaN
#                          query                           name  \
# 0  ChIJMStDGsrXDIgRyPNO_VtZBPk  Stone Ridge Square Apartments
# 1  ChIJMStDGsrXDIgRyPNO_VtZBPk  Stone Ridge Square Apartments
#
#                                google_id                     place_id  \
# 0  0x880cd7ca1a432b31:0xf904595bfd4ef3c8  ChIJMStDGsrXDIgRyPNO_VtZBPk
# 1  0x880cd7ca1a432b31:0xf904595bfd4ef3c8  ChIJMStDGsrXDIgRyPNO_VtZBPk
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Stone+Ridge+...
# 1  https://www.google.com/maps/place/Stone+Ridge+...
#
#                                         reviews_link  reviews  rating  \
# 0  https://search.google.com/local/reviews?placei...       78     4.5
# 1  https://search.google.com/local/reviews?placei...       78     4.5
#
#                               review_id review_pagination_id  \
# 0   ChZDSUhNMG9nS0VJQ0FnSUNKOXFyTkt3EAE     CAESBkVnSUlBUQ==
# 1  ChdDSUhNMG9nS0VJQ0FnSUNKOXJYbDRRRRAB     CAESBkVnSUlBZw==
#
#                                          author_link author_title  \
# 0  https://www.google.com/maps/contrib/1074535517...  Holly Black
# 1  https://www.google.com/maps/contrib/1090321903...  Gerry Green
#
#                author_id                                       author_image  \
# 0  107453551701555172701  https://lh3.googleusercontent.com/a-/ALV-UjXGu...
# 1  109032190359447956486  https://lh3.googleusercontent.com/a/ACg8ocJUiY...
#
#                                          review_text review_img_url  \
# 0  Stone Ridge Square is a fantastic housing opti...            NaN
# 1  I have lived here at Stone Ridge for more than...            NaN
#
#   review_img_urls  review_questions review_photo_ids owner_answer  \
# 0             NaN               NaN              NaN          NaN
# 1             NaN               NaN              NaN          NaN
#
#    owner_answer_timestamp owner_answer_timestamp_datetime_utc  \
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
#
#                                          review_link  review_rating  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...              5
# 1  https://www.google.com/maps/reviews/data=!4m8!...              5
#
#    review_timestamp  review_datetime_utc  review_likes          reviews_id  \
# 0        1687833923  06/27/2023 02:45:23             0 -503179006731947064
# 1        1687840790  06/27/2023 04:39:50             0 -503179006731947064
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                    5                    3                    1
# 1                    5                    3                    1
#
#    reviews_per_score_4  reviews_per_score_5
# 0                   11                   58
# 1                   11                   58

# %% [markdown]
# ### NLP
#
# Read the token list (through spaCy) and sentiment analysis results (using DistilBERT) so that you don't have to run the entire text analysis (which can take over an hour).

# %%
df_tokens = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/results/tokens.csv.gz')
df_sentiments = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/results/sentiments.csv')

display(df_tokens.head(3))
display(df_sentiments.head(3))
# Out:
#                               review_id      text    lemma    explain
# 0  ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB   Service  service       noun
# 1  ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB  requests  request       noun
# 2  ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB      long     long  adjective
#                               review_id sentiment     score
# 0  ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB  POSITIVE  0.909106
# 1   ChZDSUhNMG9nS0VJQ0FnSUNwOUstOVpBEAE  NEGATIVE  0.999216
# 2   ChZDSUhNMG9nS0VJQ0FnSURwbGZXTUJ3EAE  NEGATIVE  0.998690
