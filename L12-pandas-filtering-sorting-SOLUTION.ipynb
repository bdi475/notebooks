# %% [markdown]
# # Lecture 12 - Pandas Filtering Recap, Sorting
#
# Thursday 2021/09/30

# %% [markdown]
# ## Lecture Notes and in-class exercises

# %% [markdown]
# ▶️ First, run the code cell below to import `unittest`, a module used for **🧭 Check Your Work** sections and the autograder.

# %%
import unittest
tc = unittest.TestCase()

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Import the following Python packages.
#     1. `pandas`: Use alias `pd`.
#     2. `numpy`: Use alias `np`.

# %%
# YOUR CODE BEGINS
import pandas as pd
import numpy as np
# YOUR CODE ENDS

# %% [markdown]
# #### 🧭 Check your work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix any parts that cause the error.

# %%
import sys
tc.assertTrue("pd" in globals(), "Check whether you have correctly import Pandas with an alias.")
tc.assertTrue("np" in globals(), "Check whether you have correctly import NumPy with an alias.")

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find John's positive transaction(s)

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Given `df`, find rows where the name is `'John'` **and** the amount is positive.
#     - Store the result to a new variable named `df_john_pos`.
#     - `df_john_and_pos` should be a `DataFrame`.
# - ✔️ `df` should remain unaltered after running your code.

# %% [markdown]
# #### 🚀 Hints
#
# - Create a boolean Series `is_john` using an equality comparison (`df['name'] == 'John'`).
# - Create another boolean Series `is_positive` using a *greather than* comparison (`df['amount'] > 0`).
# - Use a logical AND operator `&` to combine `is_john` and `is_positive`.

# %% [markdown]
# ▶️ Run the code cell below to create `df`.

# %%
# DO NOT CHANGE THE CODE IN THIS CELL
df = pd.DataFrame({"name": ["John", "Mary", "Tom", "John"], "amount": [-20, -10, 10, 20]})
df
# Out:
#    name  amount
# 0  John     -20
# 1  Mary     -10
# 2   Tom      10
# 3  John      20

# %%
# YOUR CODE BEGINS
is_john = df["name"] == "John"
is_positive = df["amount"] > 0

df_john_and_pos = df[is_john & is_positive]
# YOUR CODE ENDS

df_john_and_pos
# Out:
#    name  amount
# 3  John      20

# %% [markdown]
# #### 🧭 Check your work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_check = pd.DataFrame({"name": ["John", "Mary", "Tom", "John"], "amount": [-20, -10, 10, 20]})

pd.testing.assert_frame_equal(df, df_check)
pd.testing.assert_frame_equal(df_john_and_pos.reset_index(drop=True),
                              df_check.iloc[[3]].reset_index(drop=True))

# %% [markdown]
# #### ⚜️ A diagram to help your understanding
# ![is_john_AND_is_positive](https://github.com/bdi475/images/blob/main/is-john-AND-is-positive.png?raw=true)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find transactions that are made by John OR are positive

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Given `df`, find rows where the name is `'John'` **or** the amount is positive.
#     - Store the result to a new variable named `df_john_or_pos`.
#     - `df_john_or_pos` should be a `DataFrame`.
# - ✔️ `df` should remain unaltered after running your code.

# %% [markdown]
# #### 🚀 Hints
#
# - Create a boolean Series `is_john` using an equality comparison (`df['name'] == 'John'`).
# - Create another boolean Series `is_positive` using a *greather than* comparison (`df['amount'] > 0`).
# - Use a logical OR operator `|` to combine `is_john` and `is_positive`.

# %% [markdown]
# ▶️ Run the code cell below to create `df`.

# %%
# DO NOT CHANGE THE CODE IN THIS CELL
df = pd.DataFrame({"name": ["John", "Mary", "Tom", "John"], "amount": [-20, -10, 10, 20]})
df
# Out:
#    name  amount
# 0  John     -20
# 1  Mary     -10
# 2   Tom      10
# 3  John      20

# %%
# YOUR CODE BEGINS
is_john = df["name"] == "John"
is_positive = df["amount"] > 0

df_john_or_pos = df[is_john | is_positive]
# YOUR CODE ENDS

df_john_or_pos
# Out:
#    name  amount
# 0  John     -20
# 2   Tom      10
# 3  John      20

# %% [markdown]
# #### 🧭 Check your work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_check = pd.DataFrame({"name": ["John", "Mary", "Tom", "John"], "amount": [-20, -10, 10, 20]})

pd.testing.assert_frame_equal(df, df_check)
pd.testing.assert_frame_equal(df_john_or_pos.reset_index(drop=True),
                              df_check.iloc[[0, 2, 3]].reset_index(drop=True))

# %% [markdown]
# #### ⚜️ A diagram to help your understanding
# ![is_john_OR_is_positive](https://github.com/bdi475/images/blob/main/is-john-OR-is-positive.png?raw=true)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find transactions that are NOT made by John

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Given `df`, find rows where the name is NOT `'John'`.
#     - Store the result to a new variable named `df_not_john`.
#     - `df_not_john` should be a `DataFrame`.
# - ✔️ Although you can do this without the NOT operator (`~`), **your goal is to use `~`**.
# - ✔️ `df` should remain unaltered after running your code.

# %% [markdown]
# #### 🚀 Hints
#
# - Create a boolean Series `is_john` using an equality comparison (`df['name'] == 'John'`).
# - Use a logical NOT operator `~` to reverse `is_john`.

# %% [markdown]
# ▶️ Run the code cell below to create `df`.

# %%
# DO NOT CHANGE THE CODE IN THIS CELL
df = pd.DataFrame({"name": ["John", "Mary", "Tom", "John"], "amount": [-20, -10, 10, 20]})
df
# Out:
#    name  amount
# 0  John     -20
# 1  Mary     -10
# 2   Tom      10
# 3  John      20

# %%
# YOUR CODE BEGINS
is_john = df["name"] == "John"

df_not_john = df[~is_john]
# YOUR CODE ENDS

df_not_john
# Out:
#    name  amount
# 1  Mary     -10
# 2   Tom      10

# %% [markdown]
# #### 🧭 Check your work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_check = pd.DataFrame({"name": ["John", "Mary", "Tom", "John"], "amount": [-20, -10, 10, 20]})

pd.testing.assert_frame_equal(df, df_check)
pd.testing.assert_frame_equal(df_not_john.reset_index(drop=True),
                              df_check.iloc[[1, 2]].reset_index(drop=True))

# %% [markdown]
# #### ⚜️ A diagram to help your understanding
# ![not_john](https://github.com/bdi475/images/blob/main/not-john.png?raw=true)

# %% [markdown]
# ---
#
# ## Exercises using a dataset about you
#
# ### 📌 Load data
#
# ▶️ Run the code cell below to create a new `DataFrame` named `df_you`.

# %%
df_you = pd.read_csv("https://raw.githubusercontent.com/bdi475/datasets/main/about-you.csv")

# Used to keep a clean copy
df_you_backup = df_you.copy()

# head() displays the first 5 rows of a DataFrame
df_you.head()
# Out:
#         name            major1               major2        city  \
# 0     Khalid  Computer Science                  NaN     Fairfax
# 1  Ana Maria         Nondegree                  NaN   Bucharest
# 2    Aishani           Finance                  NaN  Naperville
# 3     Joshua       Advertising                  NaN     Chicago
# 4     Adrian           Finance  Information Systems   Grayslake
#
#    distance_from_champaign       fav_restaurant                 fav_movie  \
# 0                   713.45          Chick-fil-a           Ford vs Ferrari
# 1                  5313.00                  NaN                       NaN
# 2                   115.46  Noodles and Company                 The Mummy
# 3                   125.86           Soho House  The Shawshank Redemption
# 4                   180.82   Choong Man Chicken                 Inception
#
#    has_iphone
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True

# %% [markdown]
# The table below describes the columns in `df_you`.
#
# | Column Name             | Description                                               |
# |-------------------------|-----------------------------------------------------------|
# | name                    | First name                                                |
# | major1                  | Major                                                     |
# | major2                  | Second major OR minor (blank if no second major or minor) |
# | city                    | City the person is from                                   |
# | distance_from_champaign | Straight distance from the city to Champaign in miles     |
# | fav_restaurant          | Favorite restaurant (blank if no restaurant was given)    |
# | fav_movie               | Favorite movie (blank if no movie was given)              |
# | has_iphone              | Whether the person use an iPhone                          |

# %% [markdown]
# ---
#
# ### 📌 Concise summary of a `DataFrame`

# %% [markdown]
# ▶️ Run `df_you.info()` below to see the `info()` method in action.

# %%
# YOUR CODE BEGINS
df_you.info()
# YOUR CODE ENDS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     21 non-null     object
#  1   major1                   21 non-null     object
#  2   major2                   9 non-null      object
#  3   city                     20 non-null     object
#  4   distance_from_champaign  19 non-null     float64
#  5   fav_restaurant           19 non-null     object
#  6   fav_movie                16 non-null     object
#  7   has_iphone               21 non-null     bool
# dtypes: bool(1), float64(1), object(6)
# memory usage: 1.3+ KB

# %% [markdown]
# ---
#
# ### 📌 Number of rows and columns in a `DataFrame`

# %% [markdown]
# 👉 How many rows and columns does `df_you` have?
#
# ▶️ Run `df_you.shape` below to see the *shape* of the database.

# %%
# YOUR CODE BEGINS
df_you.shape
# YOUR CODE ENDS
# Out:
# (21, 8)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find of number of rows and columns in a `DataFrame`

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Store the number of rows in `df_you` to a new variable named `num_rows`.
# - ✔️ Store the number of columns in `df_you` to a new variable named `num_cols`.
# - ✔️ Use `.shape`, not `len()`.

# %%
# YOUR CODE BEGINS
num_rows = df_you.shape[0]
num_cols = df_you.shape[1]
# YOUR CODE ENDS

print(num_rows)
print(num_cols)
# Out:
# 21
# 8

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
tc.assertEqual(num_rows, len(df_you.index), f"Number of rows should be {len(df_you.index)}")
tc.assertEqual(num_cols, len(df_you.columns), f"Number of columns should be {len(df_you.columns)}")

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: People who does not use an iPhone

# %% [markdown]
# ▶️ Run the code cell below to see the **first** 3 rows of `df_you`.

# %%
# Restore clean df_you
df_you = df_you_backup.copy()

df_you.head(3)
# Out:
#         name            major1 major2        city  distance_from_champaign  \
# 0     Khalid  Computer Science    NaN     Fairfax                   713.45
# 1  Ana Maria         Nondegree    NaN   Bucharest                  5313.00
# 2    Aishani           Finance    NaN  Naperville                   115.46
#
#         fav_restaurant        fav_movie  has_iphone
# 0          Chick-fil-a  Ford vs Ferrari       False
# 1                  NaN              NaN        True
# 2  Noodles and Company        The Mummy        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person does not use an iPhone.
#     - Store the result to a new variable named `df_no_iphone`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_no_iphone = df_you[~df_you["has_iphone"]]
# YOUR CODE ENDS

df_no_iphone
# Out:
#      name            major1            major2     city  \
# 0  Khalid  Computer Science               NaN  Fairfax
# 3  Joshua       Advertising               NaN  Chicago
# 9   Colby        Statistics  Computer Science  Fremont
#
#    distance_from_champaign fav_restaurant                 fav_movie  \
# 0                   713.45    Chick-fil-a           Ford vs Ferrari
# 3                   125.86     Soho House  The Shawshank Redemption
# 9                  2169.00       Cravings              TRON: Legacy
#
#    has_iphone
# 0       False
# 3       False
# 9       False

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
pd.testing.assert_frame_equal(df_no_iphone.reset_index(drop=True),
                              df_you[~df_you["has_iphone"]].reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: People who are within 150 miles radius from Champaign.

# %% [markdown]
# ▶️ Run the code cell below to see the **last** 2 rows of `df_you`.

# %%
# Restore clean df_you
df_you = df_you_backup.copy()

df_you.tail(2)
# Out:
#        name      major1            major2       city  distance_from_champaign  \
# 19  Sarvani  Psychology               NaN  Grayslake                   180.82
# 20      Leo  Statistics  Computer Science       Wuxi                  7158.00
#
#    fav_restaurant               fav_movie  has_iphone
# 19       Big Bowl  The Trial of Chicago 7        True
# 20        Shiquan            Interstellar        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person is from a city that is within 150 miles from Champaign.
#     - Use the `distance_from_champaign` column.
#     - Store the result to a new variable named `df_nearby`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_nearby = df_you[df_you["distance_from_champaign"] <= 150]
# YOUR CODE ENDS

df_nearby
# Out:
#          name            major1                major2           city  \
# 2     Aishani           Finance                   NaN     Naperville
# 3      Joshua       Advertising                   NaN        Chicago
# 6         Mia  Computer Science                   NaN        Chicago
# 11       Rhea        Psychology              Business        Chicago
# 14  Jaqueline       Mathematics            Statistics        Chicago
# 15       Kyle      Econometrics  Quantative Economics  Highland Park
# 17       Luke           Finance                   NaN         Urbana
#
#     distance_from_champaign       fav_restaurant                 fav_movie  \
# 2                    115.46  Noodles and Company                 The Mummy
# 3                    125.86           Soho House  The Shawshank Redemption
# 6                    125.86         Olive Garden                   Sabrina
# 11                   125.86          RPM Italian                       NaN
# 14                   125.86        Falco's Pizza              Stepbrothers
# 15                   144.55             Tsu Kasa       Wolf of Wall Street
# 17                     2.00      Pizzaria Antica                       NaN
#
#     has_iphone
# 2         True
# 3        False
# 6         True
# 11        True
# 14        True
# 15        True
# 17        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_check = df_you_backup[df_you_backup["distance_from_champaign"] <= 150]

pd.testing.assert_frame_equal(df_nearby.sort_values(df_nearby.columns.tolist()).reset_index(drop=True),
                              df_check.sort_values(df_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: People who like Chipotle

# %% [markdown]
# ▶️ Run the code cell below to **randomly select** 3 rows from `df_you`.

# %%
# Restore clean df_you
df_you = df_you_backup.copy()

df_you.sample(3)
# Out:
#      name            major1      major2      city  distance_from_champaign  \
# 7    Adam         Economics  Statistics  Rockford                   184.22
# 6     Mia  Computer Science         NaN   Chicago                   125.86
# 3  Joshua       Advertising         NaN   Chicago                   125.86
#
#   fav_restaurant                 fav_movie  has_iphone
# 7   Seven Saints                 John Wick        True
# 6   Olive Garden                   Sabrina        True
# 3     Soho House  The Shawshank Redemption       False

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows where the person's favorite restaurant is `Chipotle`.
#     - Store the result to a new variable named `df_chipotle`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_chipotle = df_you[df_you["fav_restaurant"] == "Chipotle"]
# YOUR CODE ENDS

df_chipotle
# Out:
#        name                major1    major2        city  \
# 12  Michael  Information Sciences  Business  Northbrook
#
#     distance_from_champaign fav_restaurant fav_movie  has_iphone
# 12                   158.81       Chipotle  Rounders        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_check = df_you_backup[df_you_backup["fav_restaurant"] == "Chipotle"]

pd.testing.assert_frame_equal(df_chipotle.sort_values(df_chipotle.columns.tolist()).reset_index(drop=True),
                              df_check.sort_values(df_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: `Finance` or `Advertising` people

# %% [markdown]
# ▶️ Run the code cell below to see the **last** 5 rows of `df_you`.

# %%
# Restore clean df_you
df_you = df_you_backup.copy()

df_you.tail(5)
# Out:
#        name       major1            major2       city  \
# 16   Sean W  Mathematics               NaN        NaN
# 17     Luke      Finance               NaN     Urbana
# 18   Sean S  Advertising               NaN     Taipei
# 19  Sarvani   Psychology               NaN  Grayslake
# 20      Leo   Statistics  Computer Science       Wuxi
#
#     distance_from_champaign   fav_restaurant               fav_movie  \
# 16                      NaN              NaN                     NaN
# 17                     2.00  Pizzaria Antica                     NaN
# 18                  7539.00      Dragon Gate     Let the Bullets Fly
# 19                   180.82         Big Bowl  The Trial of Chicago 7
# 20                  7158.00          Shiquan            Interstellar
#
#     has_iphone
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Using `df_you`, filter rows that matches the following criteria:
#     - The person's `major1` is `Finance`, **OR**
#     - The person's `major1` is `Advertising`.
# - ✔️ Store the filtered `DataFrame` to a new variable named `df_fin_adv`.
# - ✔️ `df_you` should remain unaltered after your code.

# %%
# YOUR CODE BEGINS
df_fin_adv = df_you[(df_you["major1"] == "Finance") | (df_you["major1"] == "Advertising")]
# YOUR CODE ENDS

df_fin_adv
# Out:
#        name       major1               major2        city  \
# 2   Aishani      Finance                  NaN  Naperville
# 3    Joshua  Advertising                  NaN     Chicago
# 4    Adrian      Finance  Information Systems   Grayslake
# 17     Luke      Finance                  NaN      Urbana
# 18   Sean S  Advertising                  NaN      Taipei
#
#     distance_from_champaign       fav_restaurant                 fav_movie  \
# 2                    115.46  Noodles and Company                 The Mummy
# 3                    125.86           Soho House  The Shawshank Redemption
# 4                    180.82   Choong Man Chicken                 Inception
# 17                     2.00      Pizzaria Antica                       NaN
# 18                  7539.00          Dragon Gate       Let the Bullets Fly
#
#     has_iphone
# 2         True
# 3        False
# 4         True
# 17        True
# 18        True

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_check = df_you_backup[(df_you_backup["major1"] == "Finance") | (df_you_backup["major1"] == "Advertising")]

pd.testing.assert_frame_equal(df_fin_adv.sort_values(df_fin_adv.columns.tolist()).reset_index(drop=True),
                              df_check.sort_values(df_check.columns.tolist()).reset_index(drop=True))

# %% [markdown]
# ---
#
# ## 👉 Sorting a `DataFrame`
#
# You can sort a `DataFrame` using `df.sort_values()`.

# %% [markdown]
# ![sort_values usage](https://github.com/bdi475/images/blob/main/pandas/sort-values-01.png?raw=true)

# %% [markdown]
# ▶️ Run the code cell below to **sort** `df_you` by `distance_from_champaign`.

# %%
df_you.sort_values('distance_from_champaign')
# Out:
#          name                major1                major2           city  \
# 17       Luke               Finance                   NaN         Urbana
# 2     Aishani               Finance                   NaN     Naperville
# 3      Joshua           Advertising                   NaN        Chicago
# 6         Mia      Computer Science                   NaN        Chicago
# 11       Rhea            Psychology              Business        Chicago
# 14  Jaqueline           Mathematics            Statistics        Chicago
# 15       Kyle          Econometrics  Quantative Economics  Highland Park
# 12    Michael  Information Sciences              Business     Northbrook
# 13        Eli   Systems Engineering                   NaN   Lincolnshire
# 4      Adrian               Finance   Information Systems      Grayslake
# 19    Sarvani            Psychology                   NaN      Grayslake
# 7        Adam             Economics            Statistics       Rockford
# 0      Khalid      Computer Science                   NaN        Fairfax
# 9       Colby            Statistics      Computer Science        Fremont
# 10      Dylan           Mathematics             Chemistry         London
# 1   Ana Maria             Nondegree                   NaN      Bucharest
# 20        Leo            Statistics      Computer Science           Wuxi
# 8       Talal  Information Sciences                   NaN          Dubai
# 18     Sean S           Advertising                   NaN         Taipei
# 5       Anika  Information Sciences                   NaN     Barrington
# 16     Sean W           Mathematics                   NaN            NaN
#
#     distance_from_champaign            fav_restaurant  \
# 17                     2.00           Pizzaria Antica
# 2                    115.46       Noodles and Company
# 3                    125.86                Soho House
# 6                    125.86              Olive Garden
# 11                   125.86               RPM Italian
# 14                   125.86             Falco's Pizza
# 15                   144.55                  Tsu Kasa
# 12                   158.81                  Chipotle
# 13                   164.07                     Maize
# 4                    180.82        Choong Man Chicken
# 19                   180.82                  Big Bowl
# 7                    184.22              Seven Saints
# 0                    713.45               Chick-fil-a
# 9                   2169.00                  Cravings
# 10                  4051.00                 Fast Food
# 1                   5313.00                       NaN
# 20                  7158.00                   Shiquan
# 8                   7345.00            Kabobi Persian
# 18                  7539.00               Dragon Gate
# 5                       NaN  California Pizza Kitchen
# 16                      NaN                       NaN
#
#                    fav_movie  has_iphone
# 17                       NaN        True
# 2                  The Mummy        True
# 3   The Shawshank Redemption       False
# 6                    Sabrina        True
# 11                       NaN        True
# 14              Stepbrothers        True
# 15       Wolf of Wall Street        True
# 12                  Rounders        True
# 13                    Wall-E        True
# 4                  Inception        True
# 19    The Trial of Chicago 7        True
# 7                  John Wick        True
# 0            Ford vs Ferrari       False
# 9               TRON: Legacy       False
# 10                       NaN        True
# 1                        NaN        True
# 20              Interstellar        True
# 8              Monsters Inc.        True
# 18       Let the Bullets Fly        True
# 5                  Goldfinch        True
# 16                       NaN        True

# %% [markdown]
# ▶️ Run the code cell below to **sort** `df_you` by `major1` and then by `major2` for people with same `major1` values.

# %%
df_you.sort_values(["major1", "major2"])
# Out:
#          name                major1                major2           city  \
# 3      Joshua           Advertising                   NaN        Chicago
# 18     Sean S           Advertising                   NaN         Taipei
# 0      Khalid      Computer Science                   NaN        Fairfax
# 6         Mia      Computer Science                   NaN        Chicago
# 15       Kyle          Econometrics  Quantative Economics  Highland Park
# 7        Adam             Economics            Statistics       Rockford
# 4      Adrian               Finance   Information Systems      Grayslake
# 2     Aishani               Finance                   NaN     Naperville
# 17       Luke               Finance                   NaN         Urbana
# 12    Michael  Information Sciences              Business     Northbrook
# 5       Anika  Information Sciences                   NaN     Barrington
# 8       Talal  Information Sciences                   NaN          Dubai
# 10      Dylan           Mathematics             Chemistry         London
# 14  Jaqueline           Mathematics            Statistics        Chicago
# 16     Sean W           Mathematics                   NaN            NaN
# 1   Ana Maria             Nondegree                   NaN      Bucharest
# 11       Rhea            Psychology              Business        Chicago
# 19    Sarvani            Psychology                   NaN      Grayslake
# 9       Colby            Statistics      Computer Science        Fremont
# 20        Leo            Statistics      Computer Science           Wuxi
# 13        Eli   Systems Engineering                   NaN   Lincolnshire
#
#     distance_from_champaign            fav_restaurant  \
# 3                    125.86                Soho House
# 18                  7539.00               Dragon Gate
# 0                    713.45               Chick-fil-a
# 6                    125.86              Olive Garden
# 15                   144.55                  Tsu Kasa
# 7                    184.22              Seven Saints
# 4                    180.82        Choong Man Chicken
# 2                    115.46       Noodles and Company
# 17                     2.00           Pizzaria Antica
# 12                   158.81                  Chipotle
# 5                       NaN  California Pizza Kitchen
# 8                   7345.00            Kabobi Persian
# 10                  4051.00                 Fast Food
# 14                   125.86             Falco's Pizza
# 16                      NaN                       NaN
# 1                   5313.00                       NaN
# 11                   125.86               RPM Italian
# 19                   180.82                  Big Bowl
# 9                   2169.00                  Cravings
# 20                  7158.00                   Shiquan
# 13                   164.07                     Maize
#
#                    fav_movie  has_iphone
# 3   The Shawshank Redemption       False
# 18       Let the Bullets Fly        True
# 0            Ford vs Ferrari       False
# 6                    Sabrina        True
# 15       Wolf of Wall Street        True
# 7                  John Wick        True
# 4                  Inception        True
# 2                  The Mummy        True
# 17                       NaN        True
# 12                  Rounders        True
# 5                  Goldfinch        True
# 8              Monsters Inc.        True
# 10                       NaN        True
# 14              Stepbrothers        True
# 16                       NaN        True
# 1                        NaN        True
# 11                       NaN        True
# 19    The Trial of Chicago 7        True
# 9               TRON: Legacy       False
# 20              Interstellar        True
# 13                    Wall-E        True

# %% [markdown]
# ▶️ Run the code cell below to **sort** `df_you` by `distance_from_champaign` in descending order.

# %%
df_you.sort_values("distance_from_champaign", ascending=False)
# Out:
#          name                major1                major2           city  \
# 18     Sean S           Advertising                   NaN         Taipei
# 8       Talal  Information Sciences                   NaN          Dubai
# 20        Leo            Statistics      Computer Science           Wuxi
# 1   Ana Maria             Nondegree                   NaN      Bucharest
# 10      Dylan           Mathematics             Chemistry         London
# 9       Colby            Statistics      Computer Science        Fremont
# 0      Khalid      Computer Science                   NaN        Fairfax
# 7        Adam             Economics            Statistics       Rockford
# 4      Adrian               Finance   Information Systems      Grayslake
# 19    Sarvani            Psychology                   NaN      Grayslake
# 13        Eli   Systems Engineering                   NaN   Lincolnshire
# 12    Michael  Information Sciences              Business     Northbrook
# 15       Kyle          Econometrics  Quantative Economics  Highland Park
# 6         Mia      Computer Science                   NaN        Chicago
# 3      Joshua           Advertising                   NaN        Chicago
# 11       Rhea            Psychology              Business        Chicago
# 14  Jaqueline           Mathematics            Statistics        Chicago
# 2     Aishani               Finance                   NaN     Naperville
# 17       Luke               Finance                   NaN         Urbana
# 5       Anika  Information Sciences                   NaN     Barrington
# 16     Sean W           Mathematics                   NaN            NaN
#
#     distance_from_champaign            fav_restaurant  \
# 18                  7539.00               Dragon Gate
# 8                   7345.00            Kabobi Persian
# 20                  7158.00                   Shiquan
# 1                   5313.00                       NaN
# 10                  4051.00                 Fast Food
# 9                   2169.00                  Cravings
# 0                    713.45               Chick-fil-a
# 7                    184.22              Seven Saints
# 4                    180.82        Choong Man Chicken
# 19                   180.82                  Big Bowl
# 13                   164.07                     Maize
# 12                   158.81                  Chipotle
# 15                   144.55                  Tsu Kasa
# 6                    125.86              Olive Garden
# 3                    125.86                Soho House
# 11                   125.86               RPM Italian
# 14                   125.86             Falco's Pizza
# 2                    115.46       Noodles and Company
# 17                     2.00           Pizzaria Antica
# 5                       NaN  California Pizza Kitchen
# 16                      NaN                       NaN
#
#                    fav_movie  has_iphone
# 18       Let the Bullets Fly        True
# 8              Monsters Inc.        True
# 20              Interstellar        True
# 1                        NaN        True
# 10                       NaN        True
# 9               TRON: Legacy       False
# 0            Ford vs Ferrari       False
# 7                  John Wick        True
# 4                  Inception        True
# 19    The Trial of Chicago 7        True
# 13                    Wall-E        True
# 12                  Rounders        True
# 15       Wolf of Wall Street        True
# 6                    Sabrina        True
# 3   The Shawshank Redemption       False
# 11                       NaN        True
# 14              Stepbrothers        True
# 2                  The Mummy        True
# 17                       NaN        True
# 5                  Goldfinch        True
# 16                       NaN        True

# %% [markdown]
# ▶️ Run the code cell below to **sort** `df_you` by `major1` in descending order and **then** by `city` in ascending order within each `major1`.

# %%
df_you.sort_values(["major1", "city"], ascending=[False, True])
# Out:
#          name                major1                major2           city  \
# 13        Eli   Systems Engineering                   NaN   Lincolnshire
# 9       Colby            Statistics      Computer Science        Fremont
# 20        Leo            Statistics      Computer Science           Wuxi
# 11       Rhea            Psychology              Business        Chicago
# 19    Sarvani            Psychology                   NaN      Grayslake
# 1   Ana Maria             Nondegree                   NaN      Bucharest
# 14  Jaqueline           Mathematics            Statistics        Chicago
# 10      Dylan           Mathematics             Chemistry         London
# 16     Sean W           Mathematics                   NaN            NaN
# 5       Anika  Information Sciences                   NaN     Barrington
# 8       Talal  Information Sciences                   NaN          Dubai
# 12    Michael  Information Sciences              Business     Northbrook
# 4      Adrian               Finance   Information Systems      Grayslake
# 2     Aishani               Finance                   NaN     Naperville
# 17       Luke               Finance                   NaN         Urbana
# 7        Adam             Economics            Statistics       Rockford
# 15       Kyle          Econometrics  Quantative Economics  Highland Park
# 6         Mia      Computer Science                   NaN        Chicago
# 0      Khalid      Computer Science                   NaN        Fairfax
# 3      Joshua           Advertising                   NaN        Chicago
# 18     Sean S           Advertising                   NaN         Taipei
#
#     distance_from_champaign            fav_restaurant  \
# 13                   164.07                     Maize
# 9                   2169.00                  Cravings
# 20                  7158.00                   Shiquan
# 11                   125.86               RPM Italian
# 19                   180.82                  Big Bowl
# 1                   5313.00                       NaN
# 14                   125.86             Falco's Pizza
# 10                  4051.00                 Fast Food
# 16                      NaN                       NaN
# 5                       NaN  California Pizza Kitchen
# 8                   7345.00            Kabobi Persian
# 12                   158.81                  Chipotle
# 4                    180.82        Choong Man Chicken
# 2                    115.46       Noodles and Company
# 17                     2.00           Pizzaria Antica
# 7                    184.22              Seven Saints
# 15                   144.55                  Tsu Kasa
# 6                    125.86              Olive Garden
# 0                    713.45               Chick-fil-a
# 3                    125.86                Soho House
# 18                  7539.00               Dragon Gate
#
#                    fav_movie  has_iphone
# 13                    Wall-E        True
# 9               TRON: Legacy       False
# 20              Interstellar        True
# 11                       NaN        True
# 19    The Trial of Chicago 7        True
# 1                        NaN        True
# 14              Stepbrothers        True
# 10                       NaN        True
# 16                       NaN        True
# 5                  Goldfinch        True
# 8              Monsters Inc.        True
# 12                  Rounders        True
# 4                  Inception        True
# 2                  The Mummy        True
# 17                       NaN        True
# 7                  John Wick        True
# 15       Wolf of Wall Street        True
# 6                    Sabrina        True
# 0            Ford vs Ferrari       False
# 3   The Shawshank Redemption       False
# 18       Let the Bullets Fly        True

# %% [markdown]
# ---
#
# ## Exercises using the Yeezys dataset
#
# ### 📌 Load data
#
# ▶️ Run the code cell below to create a new `DataFrame` named `df_sneakers`.

# %%
df_sneakers = pd.read_csv("https://raw.githubusercontent.com/bdi475/datasets/main/yeezy_sneakers.csv")

# Used to keep a clean copy
df_sneakers_backup = df_sneakers.copy()

# head() displays the first 5 rows of a DataFrame
df_sneakers.head()
# Out:
#     brand                                 product  price
# 0  Adidas             Yeezy 750 Boost Light Brown   1578
# 1  Adidas            Yeezy 350 Boost Pirate Black    910
# 2  Adidas  Yeezy Boost 350 V2 Lundmark Reflective   1009
# 3  Adidas            Yeezy 350 Boost V2 Black/Red    954
# 4    Nike                         Air Yeezy Blink   3142

# %% [markdown]
# The table below describes the columns in `df_sneakers`.
#
# | Column Name             | Description           |
# |-------------------------|-----------------------|
# | brand                   | Brand of the sneaker  |
# | product                 | Name of the sneaker   |
# | price                   | Price of the sneaker  |

# %% [markdown]
# ---
#
# ### 📌 Concise summary of a `DataFrame`

# %% [markdown]
# ▶️ Print out a summary of the `df_sneakers` using the `info()` method.

# %%
# YOUR CODE BEGINS
df_sneakers.info()
# YOUR CODE ENDS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   brand    15 non-null     object
#  1   product  15 non-null     object
#  2   price    15 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 488.0+ bytes

# %% [markdown]
# ---
#
# ### 📌 Number of rows and columns in a `DataFrame`

# %% [markdown]
# 👉 How many rows and columns does `df_sneakers` have?
#
# ▶️ Run `df_sneakers.shape` below to see the *shape* of the database.

# %%
# YOUR CODE BEGINS
df_sneakers.shape
# YOUR CODE ENDS
# Out:
# (15, 3)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find the number of rows and columns in a `DataFrame`

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Store the number of rows in `df_sneakers` to a new variable named `num_rows`.
# - ✔️ Store the number of columns in `df_sneakers` to a new variable named `num_cols`.
# - ✔️ Use `.shape`, not `len()`.

# %%
# YOUR CODE BEGINS
num_rows = df_sneakers.shape[0]
num_cols = df_sneakers.shape[1]
# YOUR CODE ENDS

print(num_rows)
print(num_cols)
# Out:
# 15
# 3

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
tc.assertEqual(num_rows, len(df_sneakers.index), f"Number of rows should be {len(df_sneakers.index)}")
tc.assertEqual(num_cols, len(df_sneakers.columns), f"Number of columns should be {len(df_sneakers.columns)}")

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find `Adidas` sneakers

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Find Adidas sneakers and store the filtered result to `df_adidas`.
# - ✔️ `df_sneakers` should remain unaltered.

# %%
# YOUR CODE BEGINS
df_adidas = df_sneakers[df_sneakers["brand"] == "Adidas"]
# YOUR CODE ENDS

df_adidas
# Out:
#      brand                                 product  price
# 0   Adidas             Yeezy 750 Boost Light Brown   1578
# 1   Adidas            Yeezy 350 Boost Pirate Black    910
# 2   Adidas  Yeezy Boost 350 V2 Lundmark Reflective   1009
# 3   Adidas            Yeezy 350 Boost V2 Black/Red    954
# 10  Adidas     Yeezy Boost 350 V2 Black Reflective   1437
# 11  Adidas    Yeezy Boost 350 V2 Antlia Reflective    912
# 12  Adidas     Yeezy Boost 350 V2 Synth Reflective   1292
# 13  Adidas              Yeezy 350 Boost Turtledove   1279
# 14  Adidas        Yeezy 750 Boost Glow in the Dark    917

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_sneakers_copy \
        .query("brand == 'Adidas'") \
        .sort_values(df_sneakers_copy.columns.to_list()) \
        .reset_index(drop=True),
    df_adidas.reset_index(drop=True) \
        .sort_values(df_adidas.columns.to_list()) \
        .reset_index(drop=True)
)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find `Sneakers` under \\$1,000

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Find sneakers under \\$1,000 and store the filtered result to `df_under_1000`.
# - ✔️ `df_sneakers` should remain unaltered.

# %%
# YOUR CODE BEGINS
df_under_1000 = df_sneakers[df_sneakers["price"] < 1000]
# YOUR CODE ENDS

df_under_1000
# Out:
#      brand                               product  price
# 1   Adidas          Yeezy 350 Boost Pirate Black    910
# 3   Adidas          Yeezy 350 Boost V2 Black/Red    954
# 11  Adidas  Yeezy Boost 350 V2 Antlia Reflective    912
# 14  Adidas      Yeezy 750 Boost Glow in the Dark    917

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_sneakers_copy \
        .query("price < 1000") \
        .sort_values(df_sneakers_copy.columns.to_list()) \
        .reset_index(drop=True),
    df_under_1000.reset_index(drop=True) \
        .sort_values(df_under_1000.columns.to_list()) \
        .reset_index(drop=True)
)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find Nike `Sneakers` over \\$3,000

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Find Nike sneakers over \\$3,000 and store the filtered result to `df_nike_over_3000`.
# - ✔️ `df_sneakers` should remain unaltered.

# %%
# YOUR CODE BEGINS
df_nike_over_3000 = df_sneakers[(df_sneakers["brand"] == "Nike") & (df_sneakers["price"] > 3000)]
# YOUR CODE ENDS

df_nike_over_3000
# Out:
#   brand                    product  price
# 4  Nike            Air Yeezy Blink   3142
# 5  Nike    Air Yeezy 2 Red October   6075
# 6  Nike      Air Yeezy 2 Solar Red   4239
# 7  Nike  Air Yeezy 2 Pure Platinum   3448

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_sneakers_copy \
        .query("(brand == 'Nike') & (price > 3000)") \
        .sort_values(df_sneakers_copy.columns.to_list()) \
        .reset_index(drop=True),
    df_nike_over_3000.reset_index(drop=True) \
        .sort_values(df_nike_over_3000.columns.to_list()) \
        .reset_index(drop=True)
)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Sort sneakers by price in descending order

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Sort sneakers by price in descending order and store the result to `df_sorted_by_price_desc`.
# - ✔️ `df_sneakers` should remain unaltered.

# %%
# YOUR CODE BEGINS
df_sorted_by_price_desc = df_sneakers.sort_values("price", ascending=False)
# YOUR CODE ENDS

df_sorted_by_price_desc
# Out:
#      brand                                 product  price
# 5     Nike                 Air Yeezy 2 Red October   6075
# 6     Nike                   Air Yeezy 2 Solar Red   4239
# 7     Nike               Air Yeezy 2 Pure Platinum   3448
# 4     Nike                         Air Yeezy Blink   3142
# 9     Nike                      Air Yeezy Zen Grey   2139
# 8     Nike                           Air Yeezy Net   1888
# 0   Adidas             Yeezy 750 Boost Light Brown   1578
# 10  Adidas     Yeezy Boost 350 V2 Black Reflective   1437
# 12  Adidas     Yeezy Boost 350 V2 Synth Reflective   1292
# 13  Adidas              Yeezy 350 Boost Turtledove   1279
# 2   Adidas  Yeezy Boost 350 V2 Lundmark Reflective   1009
# 3   Adidas            Yeezy 350 Boost V2 Black/Red    954
# 14  Adidas        Yeezy 750 Boost Glow in the Dark    917
# 11  Adidas    Yeezy Boost 350 V2 Antlia Reflective    912
# 1   Adidas            Yeezy 350 Boost Pirate Black    910

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_sorted_by_price_desc \
        .reset_index(drop=True),
    df_sneakers_copy.sort_values("price").iloc[::-1] \
        .reset_index(drop=True)
)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Sneakers `> 6000` or `< 1000`

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Find sneakers that are over \\$6,000 **or** under \\$1,000.
# - ✔️ Store the result to a new DataFrame named `df_polar`.
# - ✔️ `df_sneakers` should remain unaltered.

# %%
# YOUR CODE BEGINS
df_polar = df_sneakers[(df_sneakers["price"] > 6000) | (df_sneakers["price"] < 1000)]
# YOUR CODE ENDS

df_polar
# Out:
#      brand                               product  price
# 1   Adidas          Yeezy 350 Boost Pirate Black    910
# 3   Adidas          Yeezy 350 Boost V2 Black/Red    954
# 5     Nike               Air Yeezy 2 Red October   6075
# 11  Adidas  Yeezy Boost 350 V2 Antlia Reflective    912
# 14  Adidas      Yeezy 750 Boost Glow in the Dark    917

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_polar.reset_index(drop=True) \
        .sort_values(df_polar.columns.to_list()) \
        .reset_index(drop=True),
    df_sneakers_copy \
        .query("(price > 6000) | (price < 1000)") \
        .sort_values(df_sneakers_copy.columns.to_list()) \
        .reset_index(drop=True)
)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Sort by brand ascending and price descending

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Sort `df_sneakers` by (1) brand ascending and (2) price descending within each brand.
# - ✔️ Store the result to a new DataFrame named `df_sorted_by_brand_price`.
# - ✔️ `df_sneakers` should remain unaltered.

# %%
# YOUR CODE BEGINS
df_sorted_by_brand_price = df_sneakers.sort_values(["brand", "price"], ascending=[True, False])
# YOUR CODE ENDS

df_sorted_by_brand_price
# Out:
#      brand                                 product  price
# 0   Adidas             Yeezy 750 Boost Light Brown   1578
# 10  Adidas     Yeezy Boost 350 V2 Black Reflective   1437
# 12  Adidas     Yeezy Boost 350 V2 Synth Reflective   1292
# 13  Adidas              Yeezy 350 Boost Turtledove   1279
# 2   Adidas  Yeezy Boost 350 V2 Lundmark Reflective   1009
# 3   Adidas            Yeezy 350 Boost V2 Black/Red    954
# 14  Adidas        Yeezy 750 Boost Glow in the Dark    917
# 11  Adidas    Yeezy Boost 350 V2 Antlia Reflective    912
# 1   Adidas            Yeezy 350 Boost Pirate Black    910
# 5     Nike                 Air Yeezy 2 Red October   6075
# 6     Nike                   Air Yeezy 2 Solar Red   4239
# 7     Nike               Air Yeezy 2 Pure Platinum   3448
# 4     Nike                         Air Yeezy Blink   3142
# 9     Nike                      Air Yeezy Zen Grey   2139
# 8     Nike                           Air Yeezy Net   1888

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_sorted_by_brand_price \
        .reset_index(drop=True),
    df_sneakers_copy.sort_values(["brand", "price"], ascending=[False, True]).iloc[::-1] \
        .reset_index(drop=True)
)

# %% [markdown]
# ---
#
# ### 📌 Advanced Challenges (OPTIONAL)
#
# These exercises will use syntax that we haven't learned yet. You can give them a try using your problem-solving skills!

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find average price by brand

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Find the average price of sneakers by brand and store the result to `df_avg_by_brand`.
# - ✔️ `df_avg_by_brand` must be a Pandas `DataFrame`.
#     - **To check:** `print(type(df_avg_by_brand))` should print `<class 'pandas.core.frame.DataFrame'>`.
# - ✔️ The columns of `df_avg_by_brand` should be a flat-level index, not a multi-level index.
#     - **To check:** `print(df_avg_by_brand.columns.to_list())` should print `['brand', 'price']`.
# - ✔️ `df_sneakers` should remain unaltered.
#
# #### 🧭 Expected Output of `df_avg_by_brand`
#
# |  | brand | price |
# |---:|---:|---:|
# | 0 | Adidas | 1143.111111 |
# | 1 | Nike | 3488.500000 |

# %%
# YOUR CODE BEGINS
df_avg_by_brand = df_sneakers.groupby("brand", as_index=False).agg({
    "price": "mean"
})
# YOUR CODE ENDS

df_avg_by_brand
# Out:
#     brand        price
# 0  Adidas  1143.111111
# 1    Nike  3488.500000

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()

pd.testing.assert_frame_equal(
    df_avg_by_brand \
        .reset_index(drop=True),
    df_sneakers_copy.groupby("brand")["price"].mean().reset_index()
)

# %% [markdown]
# ---
#
# ### 🎯 Mini-exercise: Find average price and number of products by brand

# %% [markdown]
# #### 👇 Tasks
#
# - ✔️ Find the average price of sneakers by brand and store the result to `df_avg_and_count_by_brand`.
# - ✔️ `df_avg_and_count_by_brand` must be a Pandas `DataFrame`.
#     - **To check:** `print(type(df_avg_and_count_by_brand))` should print `<class 'pandas.core.frame.DataFrame'>`.
# - ✔️ The column names of `df_avg_and_count_by_brand` should be:
#     - `brand`
#     - `num_products`
#     - `avg_price`
# - ✔️ The columns of `df_avg_and_count_by_brand` should be a flat-level index, not a multi-level index.
#     - **To check:** `print(df_avg_and_count_by_brand.columns.to_list())` should print `['brand', 'num_products', 'avg_price']`.
# - ✔️ `df_sneakers` should remain unaltered.
#
# #### 🧭 Expected Output of `df_avg_and_count_by_brand`
#
# |  | brand | num_products | avg_price |
# |---:|---:|---:|---:|
# | 0 | Adidas | 9 | 1143.111111 |
# | 1 | Nike | 6 | 3488.500000 |

# %%
# YOUR CODE BEGINS
df_avg_and_count_by_brand = df_sneakers.groupby("brand", as_index=False).agg({
    "product": "count",
    "price": "mean"
}).rename(columns={
    "product": "num_products",
    "price": "avg_price"
})
# YOUR CODE ENDS

df_avg_and_count_by_brand
# Out:
#     brand  num_products    avg_price
# 0  Adidas             9  1143.111111
# 1    Nike             6  3488.500000

# %% [markdown]
# #### 🧭 Check Your Work
#
# - Once you're done, run the code cell below to test correctness.
# - ✔️ If the code cell runs without an error, you're good to move on.
# - ❌ If the code cell throws an error, go back and fix incorrect parts.

# %%
df_sneakers_copy = df_sneakers_backup.copy()
df_avg_and_count_by_brand_SOL = df_sneakers_copy.groupby("brand", as_index=False).agg({
    "product": "count",
    "price": "mean"
}).rename(columns={
    "product": "num_products",
    "price": "avg_price"
})

pd.testing.assert_frame_equal(
    df_avg_and_count_by_brand \
        .sort_values(df_avg_and_count_by_brand.columns.to_list())
        .reset_index(drop=True),
    df_avg_and_count_by_brand_SOL.reset_index(drop=True)
)
